# %% [markdown]
# <a href="https://colab.research.google.com/github/Jayneet123/D2K11/blob/main/Dwelling%20Area.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df = pd.read_csv("/content/India-2011.csv")

# %%
df.describe()
# Out:
#                   M             F
# count  2.100000e+01  2.100000e+01
# mean   3.096402e+07  2.892270e+07
# std    2.587606e+07  2.327530e+07
# min    5.400000e+03  9.386000e+03
# 25%    5.315117e+06  6.412777e+06
# 50%    2.939180e+07  2.798300e+07
# 75%    5.583382e+07  5.139592e+07
# max    6.787134e+07  6.155048e+07

# %%
df.head()
# Out:
#      Age         M         F
# 0    0-4  66474693  60446589
# 1    5-9  67871343  61550479
# 2  10-14  67034812  60621962
# 3  15-19  64221836  58538108
# 4  20-24  60553474  55814181

# %%
# !unzip "/content/archive.zip"
# Out:
# Archive:  /content/archive.zip
#   inflating: hlpca-colnames.csv
# replace india-districts-census-2011.csv? [y]es, [n]o, [A]ll, [N]one, [r]ename:

# %%
data2 = pd.read_csv("/content/data2.csv")

# %%
data2.head()
# Out:
#    State Code       State Name  District Code District Name  Tehsil Code  \
# 0           1  JAMMU & KASHMIR              1       Kupwara            0
# 1           1  JAMMU & KASHMIR              1       Kupwara            0
# 2           1  JAMMU & KASHMIR              1       Kupwara            0
# 3           1  JAMMU & KASHMIR              2        Badgam            0
# 4           1  JAMMU & KASHMIR              2        Badgam            0
#
#   Tehsil Name  Town Code/Village code  Ward No           Area Name  \
# 0     Kupwara                       0        0  District - Kupwara
# 1     Kupwara                       0        0  District - Kupwara
# 2     Kupwara                       0        0  District - Kupwara
# 3      Badgam                       0        0   District - Badgam
# 4      Badgam                       0        0   District - Badgam
#
#   Rural/Urban  ...  Contition_T_Total  Contition_T_Good  Contition_T_Livable  \
# ...

# %%
data2.describe()
# Out:
#         State Code  District Code  Tehsil Code  Town Code/Village code  \
# count  1908.000000    1908.000000       1908.0                  1908.0
# mean     17.088050     320.066038          0.0                     0.0
# std       9.392094     184.280200          0.0                     0.0
# min       1.000000       1.000000          0.0                     0.0
# 25%       9.000000     161.000000          0.0                     0.0
# 50%      18.000000     320.000000          0.0                     0.0
# 75%      24.000000     479.000000          0.0                     0.0
# max      35.000000     640.000000          0.0                     0.0
#
#        Ward No  Total Number of households  Total Number of Good  \
# count   1908.0                      1908.0           1908.000000
# mean       0.0                       100.0             53.694209
# std        0.0                         0.0             14.925468
# min        0.0                       100.0             11.500000
# ...

# %%
dataset2 = data2[["State Name","District Name","Number of Residence cum Good","Residence_cum_Livable"]]

# %%
dataset2
# Out:
#                      State Name            District Name  \
# 0               JAMMU & KASHMIR                  Kupwara
# 1               JAMMU & KASHMIR                  Kupwara
# 2               JAMMU & KASHMIR                  Kupwara
# 3               JAMMU & KASHMIR                   Badgam
# 4               JAMMU & KASHMIR                   Badgam
# ...                         ...                      ...
# 1903  ANDAMAN & NICOBAR ISLANDS  North  & Middle Andaman
# 1904  ANDAMAN & NICOBAR ISLANDS  North  & Middle Andaman
# 1905  ANDAMAN & NICOBAR ISLANDS            South Andaman
# 1906  ANDAMAN & NICOBAR ISLANDS            South Andaman
# 1907  ANDAMAN & NICOBAR ISLANDS            South Andaman
#
#       Number of Residence cum Good  Residence_cum_Livable
# 0                              1.0                    7.1
# 1                              0.9                    7.1
# 2                              0.7                    7.3
# ...

# %%
dataset2['sum'] = dataset2['Number of Residence cum Good']+ dataset2['Residence_cum_Livable']
# Out:
# <ipython-input-12-46c39c1950d2>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataset2['sum'] = dataset2['Number of Residence cum Good']+ dataset2['Residence_cum_Livable']

# %%
dataset2
# Out:
#                      State Name            District Name  \
# 0               JAMMU & KASHMIR                  Kupwara
# 1               JAMMU & KASHMIR                  Kupwara
# 2               JAMMU & KASHMIR                  Kupwara
# 3               JAMMU & KASHMIR                   Badgam
# 4               JAMMU & KASHMIR                   Badgam
# ...                         ...                      ...
# 1903  ANDAMAN & NICOBAR ISLANDS  North  & Middle Andaman
# 1904  ANDAMAN & NICOBAR ISLANDS  North  & Middle Andaman
# 1905  ANDAMAN & NICOBAR ISLANDS            South Andaman
# 1906  ANDAMAN & NICOBAR ISLANDS            South Andaman
# 1907  ANDAMAN & NICOBAR ISLANDS            South Andaman
#
#       Number of Residence cum Good  Residence_cum_Livable  sum
# 0                              1.0                    7.1  8.1
# 1                              0.9                    7.1  8.0
# 2                              0.7                    7.3  8.0
# ...

# %%
dataset2.sort_values(by=['sum'],ascending = False)
# Out:
#           State Name District Name  Number of Residence cum Good  \
# 1387  MADHYA PRADESH     Alirajpur                          17.7
# 1388  MADHYA PRADESH     Alirajpur                          17.1
# 1384  MADHYA PRADESH        Jhabua                          10.9
# 1385  MADHYA PRADESH        Jhabua                          10.8
# 1447         GUJARAT         Dohad                          10.8
# ...              ...           ...                           ...
# 1765          KERALA    Malappuram                           0.1
# 1764          KERALA     Kozhikode                           0.1
# 1763          KERALA     Kozhikode                           0.1
# 1896      PUDUCHERRY          Mahe                           0.1
# 1895      PUDUCHERRY          Mahe                           0.1
#
#       Residence_cum_Livable   sum
# 1387                   38.9  56.6
# 1388                   36.2  53.3
# 1384                   23.9  34.8
# 1385                   22.1  32.9
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
plt.figure(figsize=(10,8))
sns.barplot(dataset2['sum'],dataset2['State Name'])
plt.show()
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-4-a5cd26f43099> in <module>
#       1 data = pd.DataFrame()
#       2 for t in list:
# ----> 3     data[t] = pdr.DataReader(t, data_source='yahoo', start='2011-1-1')
#
# /usr/local/lib/python3.8/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     205                 else:
#     206                     kwargs[new_arg_name] = new_arg_value
# --> 207             return func(*args, **kwargs)
#     208
#     209         return cast(F, wrapper)
#
# /usr/local/lib/python3.8/dist-packages/pandas_datareader/data.py in DataReader(name, data_source, start, end, retry_count, pause, session, api_key)
#     368
#     369     if data_source == "yahoo":
# --> 370         return YahooDailyReader(
#     371             symbols=name,
#     372             start=start,
#
# ...

# %%
# Out:
# '0.9.0'
